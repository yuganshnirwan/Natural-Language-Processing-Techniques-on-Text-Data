# %% [markdown]
# <a href="https://colab.research.google.com/github/yuganshnirwan/Natural-Language-Processing-Techniques-on-Text-Data/blob/main/practical_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NLP Techniques
# ## Aarya Yugansh Nirwan
# ### Batch ENTC A1 25-29

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
text = "Natural language processing is interesting"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Natural', 'language', 'processing', 'is', 'interesting']

# %%
#Sentence Tokenization
from nltk.tokenize import sent_tokenize
text = "yugansh boy. edp lap class on friday. math test today."
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['yugansh boy.', 'edp lap class on friday.', 'math test today.']

# %%
#stop word removal
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words= word_tokenize(text)
filtered_words = [word for word in words if word.lower() not in stop_words]
print(filtered_words)
# Out:
# ['Natural', 'language', 'processing', 'interesting']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Stemming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
words = ["running", "runs", "ran","playing","studies","falls"]
for w in words:
  print(stemmer.stem(w))
# Out:
# run
# run
# ran
# play
# studi
# fall

# %%
#Lemmatization
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("words"))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# word

# %%
#Part-Of-Speech tagging
#POS tagging identifies grammatical roles of words
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk import pos_tag
words = word_tokenize("my name is yugansh ")
pos_tags = pos_tag(words)
pos_tags
# Out:
# [('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('yugansh', 'JJ')]

# %%
#Word Frequency Count
from nltk.probability import FreqDist
words = word_tokenize(text)
freq_dist = FreqDist(words)
print(words)
freq_dist
# Out:
# ['Natural', 'language', 'processing', 'is', 'interesting']
# FreqDist({'Natural': 1, 'language': 1, 'processing': 1, 'is': 1, 'interesting': 1})
